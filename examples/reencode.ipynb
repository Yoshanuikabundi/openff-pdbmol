# %%
import gzip
from itertools import batched
import multiprocessing
from pathlib import Path
from typing import Iterable

import polars as pl

# %%
# %%snakeviz
# import openff.pdbscan.polars.COORD_LINE_SCHEMA as schema
# import openff.pdbscan.polars.load_coords as proc_chunk

schema = {
    "id": pl.datatypes.String,
    "err": pl.datatypes.String,
    "lineNo": pl.datatypes.Int32,
    "serial": pl.datatypes.Int32,
    "name": pl.datatypes.String,
    "altLoc": pl.datatypes.String,
    "resName": pl.datatypes.String,
    "chainID": pl.datatypes.String,
    "resSeq": pl.datatypes.Int32,
    "iCode": pl.datatypes.String,
    "x": pl.datatypes.Float32,
    "y": pl.datatypes.Float32,
    "z": pl.datatypes.Float32,
    "occupancy": pl.datatypes.Float32,
    "tempFactor": pl.datatypes.Float32,
    "element": pl.datatypes.String,
    "charge": pl.datatypes.String,
    "terminated": pl.datatypes.Boolean,
    "modelNo": pl.datatypes.Int32,
    "conects": pl.datatypes.List(pl.datatypes.Int32),
}


def prepare_row(data: pl.DataFrame, path: Path):
    """
    Prepare a new row in a dataframe for a PDB file

    The dataframe is modified in place. The new row can be assigned to
    or read from as `data[colname][-1]`.
    """
    for column in data.values():
        column.append(None)
    data["id"][-1] = path.stem[3:-4]


def proc_chunk(batch: Iterable[Path]):
    data = {k: [] for k in schema}
    for path in batch:
        try:
            with gzip.open(path, "rt") as f:
                lines = f.readlines()
        except Exception as e:
            prepare_row(data, path)
            data["err"][-1] = repr(e)
            continue
        model_n = 0
        conects = {}
        for line in lines:
            if line.startswith("CONECT "):
                a = int(line[6:11])
                bs = []
                for start, stop in [(11, 16), (16, 21), (21, 26), (26, 31)]:
                    try:
                        b = int(line[start:stop])
                    except (ValueError, IndexError):
                        continue
                    bs.append(b)
                    conects.setdefault(b, set()).add(a)
                conects.setdefault(a, set()).update(bs)
        for line_n, line in enumerate(lines):
            if line.startswith("MODEL "):
                model_n = int(line[10:14])
            if line.startswith("ENDMDL "):
                model_n += 1
            if line.startswith("HETATM") or line.startswith("ATOM  "):
                prepare_row(data, path)
                data["lineNo"][-1] = line_n
                data["serial"][-1] = int(line[6:11])
                data["name"][-1] = line[12:16].strip()
                data["altLoc"][-1] = line[16].strip() or None
                data["resName"][-1] = line[17:20].strip()
                data["chainID"][-1] = line[21].strip()
                data["resSeq"][-1] = int(line[22:26])
                data["iCode"][-1] = line[26].strip() or None
                data["x"][-1] = line[30:38].strip()
                data["y"][-1] = line[38:46].strip()
                data["z"][-1] = line[46:54].strip()
                data["occupancy"][-1] = line[54:60].strip()
                data["tempFactor"][-1] = line[60:66].strip()
                data["element"][-1] = line[76:78].strip()
                data["charge"][-1] = line[78:80].strip() or None
                data["terminated"][-1] = False
                data["modelNo"][-1] = model_n
                data["conects"][-1] = list(conects.get(data["serial"][-1], []))
            if line.startswith("TER   "):
                terminated_resname = line[17:20].strip() or data["resName"][-1]
                terminated_chainid = line[21].strip() or data["chainID"][-1]
                terminated_resseq = int(line[22:26]) or data["resSeq"][-1]
                for i in range(-1, -999, -1):
                    if (
                        data["resName"][i] == terminated_resname
                        and data["chainID"][i] == terminated_chainid
                        and data["resSeq"][i] == terminated_resseq
                    ):
                        data["terminated"][i] = True
                    else:
                        break
                else:
                    assert False, "last residue too big"
    return data

# %%
# %%snakeviz

chunk_size = 20
threads = 24
datadir = Path("/home/joshmitchell/Downloads/pdb")
df = pl.DataFrame(schema=schema)

for i, batch in enumerate(batched(datadir.glob("*/*.ent.gz"), n=chunk_size * threads)):
    print("batch", i)
    with multiprocessing.Pool(processes=threads) as pool:
        batch_results = list(
            pool.imap_unordered(
                proc_chunk,
                batched(batch, chunk_size),
            )
        )
    print("concatenating results of batch", i)
    df = pl.concat(
        [df, *(pl.DataFrame(d, schema=schema) for d in batch_results)]
    )
    print("rechunking after batch", i)
    df.rechunk()
    print("done with batch", i, f"({df.estimate_size('mb')} mb)")
    if df.estimated_size('gb') >= 5:
        print("writing recent batches to file")
        df.write_parquet(datadir / "coords_parquet" / f"coords_{i}.parquet")
        df = pl.DataFrame(schema=schema)
print("writing final batches to file")
df.write_parquet(datadir / "coords_parquet" / f"coords_{i}.parquet")
# Out:
# batch 0
# concatenating results of batch 0
# rechunking after batch 0
# done with batch 0
# batch 1
# concatenating results of batch 1
# rechunking after batch 1
# done with batch 1
# batch 2
# concatenating results of batch 2
# rechunking after batch 2
# done with batch 2
# batch 3
# concatenating results of batch 3
# rechunking after batch 3
# done with batch 3
# batch 4
# concatenating results of batch 4
# rechunking after batch 4
# done with batch 4
# batch 5
# concatenating results of batch 5
# rechunking after batch 5
# done with batch 5
# batch 6
# concatenating results of batch 6
# rechunking after batch 6
# done with batch 6
# batch 7
# concatenating results of batch 7
# rechunking after batch 7
# done with batch 7
# batch 8
# concatenating results of batch 8
# rechunking after batch 8
# done with batch 8
# batch 9
# concatenating results of batch 9
# rechunking after batch 9
# done with batch 9
# batch 10
# concatenating results of batch 10
# rechunking after batch 10
# done with batch 10
# batch 11
# concatenating results of batch 11
# rechunking after batch 11
# done with batch 11
# batch 12
# concatenating results of batch 12
# rechunking after batch 12
# done with batch 12
# batch 13
# concatenating results of batch 13
# rechunking after batch 13
# done with batch 13
# batch 14
# concatenating results of batch 14
# rechunking after batch 14
# done with batch 14
# batch 15
# concatenating results of batch 15
# rechunking after batch 15
# done with batch 15
# batch 16
# concatenating results of batch 16
# rechunking after batch 16
# done with batch 16
# batch 17
# concatenating results of batch 17
# rechunking after batch 17
# done with batch 17
# batch 18
# concatenating results of batch 18
# rechunking after batch 18
# done with batch 18
# batch 19
# concatenating results of batch 19
# rechunking after batch 19
# done with batch 19
# batch 20
# concatenating results of batch 20
# rechunking after batch 20
# done with batch 20
# batch 21
# concatenating results of batch 21
# rechunking after batch 21
# done with batch 21
# batch 22
# concatenating results of batch 22
# rechunking after batch 22
# done with batch 22
# writing recent batches to file
# batch 23
# concatenating results of batch 23
# rechunking after batch 23
# done with batch 23
# batch 24
# concatenating results of batch 24
# rechunking after batch 24
# done with batch 24
# batch 25
# concatenating results of batch 25
# rechunking after batch 25
# done with batch 25
# batch 26
# concatenating results of batch 26
# rechunking after batch 26
# done with batch 26
# batch 27
# concatenating results of batch 27
# rechunking after batch 27
# done with batch 27
# batch 28
# concatenating results of batch 28
# rechunking after batch 28
# done with batch 28
# batch 29
# concatenating results of batch 29
# rechunking after batch 29
# done with batch 29
# batch 30
# concatenating results of batch 30
# rechunking after batch 30
# done with batch 30
# batch 31
# concatenating results of batch 31
# rechunking after batch 31
# done with batch 31
# batch 32
# concatenating results of batch 32
# rechunking after batch 32
# done with batch 32
# batch 33
# concatenating results of batch 33
# rechunking after batch 33
# done with batch 33
# batch 34
# concatenating results of batch 34
# rechunking after batch 34
# done with batch 34
# batch 35
# concatenating results of batch 35
# rechunking after batch 35
# done with batch 35
# batch 36
# concatenating results of batch 36
# rechunking after batch 36
# done with batch 36
# batch 37
# concatenating results of batch 37
# rechunking after batch 37
# done with batch 37
# batch 38
# concatenating results of batch 38
# rechunking after batch 38
# done with batch 38
# batch 39
# concatenating results of batch 39
# rechunking after batch 39
# done with batch 39
# batch 40
# concatenating results of batch 40
# rechunking after batch 40
# done with batch 40
# batch 41
# concatenating results of batch 41
# rechunking after batch 41
# done with batch 41
# batch 42
# concatenating results of batch 42
# rechunking after batch 42
# done with batch 42
# batch 43
# concatenating results of batch 43
# rechunking after batch 43
# done with batch 43
# batch 44
# concatenating results of batch 44
# rechunking after batch 44
# done with batch 44
# batch 45
# concatenating results of batch 45
# rechunking after batch 45
# done with batch 45
# writing recent batches to file
# batch 46
# concatenating results of batch 46
# rechunking after batch 46
# done with batch 46
# batch 47
# concatenating results of batch 47
# rechunking after batch 47
# done with batch 47
# batch 48
# concatenating results of batch 48
# rechunking after batch 48
# done with batch 48
# batch 49
# concatenating results of batch 49
# rechunking after batch 49
# done with batch 49
# batch 50
# concatenating results of batch 50
# rechunking after batch 50
# done with batch 50
# batch 51
# concatenating results of batch 51
# rechunking after batch 51
# done with batch 51
# batch 52
# concatenating results of batch 52
# rechunking after batch 52
# done with batch 52
# batch 53
# concatenating results of batch 53
# rechunking after batch 53
# done with batch 53
# batch 54
# concatenating results of batch 54
# rechunking after batch 54
# done with batch 54
# batch 55
# concatenating results of batch 55
# rechunking after batch 55
# done with batch 55
# batch 56
# concatenating results of batch 56
# rechunking after batch 56
# done with batch 56
# batch 57
# concatenating results of batch 57
# rechunking after batch 57
# done with batch 57
# batch 58
# concatenating results of batch 58
# rechunking after batch 58
# done with batch 58
# batch 59
# concatenating results of batch 59
# rechunking after batch 59
# done with batch 59
# batch 60
# concatenating results of batch 60
# rechunking after batch 60
# done with batch 60
# batch 61
# concatenating results of batch 61
# rechunking after batch 61
# done with batch 61
# batch 62
# concatenating results of batch 62
# rechunking after batch 62
# done with batch 62
# batch 63
# concatenating results of batch 63
# rechunking after batch 63
# done with batch 63
# batch 64
# concatenating results of batch 64
# rechunking after batch 64
# done with batch 64
# batch 65
# concatenating results of batch 65
# rechunking after batch 65
# done with batch 65
# batch 66
# concatenating results of batch 66
# rechunking after batch 66
# done with batch 66
# batch 67
# concatenating results of batch 67
# rechunking after batch 67
# done with batch 67
# batch 68
# concatenating results of batch 68
# rechunking after batch 68
# done with batch 68
# batch 69
# concatenating results of batch 69
# rechunking after batch 69
# done with batch 69
# writing recent batches to file
# batch 70
# concatenating results of batch 70
# rechunking after batch 70
# done with batch 70
# batch 71
# concatenating results of batch 71
# rechunking after batch 71
# done with batch 71
# batch 72
# concatenating results of batch 72
# rechunking after batch 72
# done with batch 72
# batch 73
# concatenating results of batch 73
# rechunking after batch 73
# done with batch 73
# batch 74
# concatenating results of batch 74
# rechunking after batch 74
# done with batch 74
# batch 75
# concatenating results of batch 75
# rechunking after batch 75
# done with batch 75
# batch 76
# concatenating results of batch 76
# rechunking after batch 76
# done with batch 76
# batch 77
# concatenating results of batch 77
# rechunking after batch 77
# done with batch 77
# batch 78
# concatenating results of batch 78
# rechunking after batch 78
# done with batch 78
# batch 79
# concatenating results of batch 79
# rechunking after batch 79
# done with batch 79
# batch 80
# concatenating results of batch 80
# rechunking after batch 80
# done with batch 80
# batch 81
# concatenating results of batch 81
# rechunking after batch 81
# done with batch 81
# batch 82
# concatenating results of batch 82
# rechunking after batch 82
# done with batch 82
# batch 83
# concatenating results of batch 83
# rechunking after batch 83
# done with batch 83
# batch 84
# concatenating results of batch 84
# rechunking after batch 84
# done with batch 84
# batch 85
# concatenating results of batch 85
# rechunking after batch 85
# done with batch 85
# batch 86
# concatenating results of batch 86
# rechunking after batch 86
# done with batch 86
# batch 87
# concatenating results of batch 87
# rechunking after batch 87
# done with batch 87
# batch 88
# concatenating results of batch 88
# rechunking after batch 88
# done with batch 88
# batch 89
# concatenating results of batch 89
# rechunking after batch 89
# done with batch 89
# batch 90
# concatenating results of batch 90
# rechunking after batch 90
# done with batch 90
# batch 91
# concatenating results of batch 91
# rechunking after batch 91
# done with batch 91
# batch 92
# concatenating results of batch 92
# rechunking after batch 92
# done with batch 92
# writing recent batches to file
# batch 93
# concatenating results of batch 93
# rechunking after batch 93
# done with batch 93
# batch 94
# concatenating results of batch 94
# rechunking after batch 94
# done with batch 94
# batch 95
# concatenating results of batch 95
# rechunking after batch 95
# done with batch 95
# batch 96
# concatenating results of batch 96
# rechunking after batch 96
# done with batch 96
# batch 97
# concatenating results of batch 97
# rechunking after batch 97
# done with batch 97
# batch 98
# concatenating results of batch 98
# rechunking after batch 98
# done with batch 98
# batch 99
# concatenating results of batch 99
# rechunking after batch 99
# done with batch 99
# batch 100
# concatenating results of batch 100
# rechunking after batch 100
# done with batch 100
# batch 101
# concatenating results of batch 101
# rechunking after batch 101
# done with batch 101
# batch 102
# concatenating results of batch 102
# rechunking after batch 102
# done with batch 102
# batch 103
# concatenating results of batch 103
# rechunking after batch 103
# done with batch 103
# batch 104
# concatenating results of batch 104
# rechunking after batch 104
# done with batch 104
# batch 105
# concatenating results of batch 105
# rechunking after batch 105
# done with batch 105
# batch 106
# concatenating results of batch 106
# rechunking after batch 106
# done with batch 106
# batch 107
# concatenating results of batch 107
# rechunking after batch 107
# done with batch 107
# batch 108
# concatenating results of batch 108
# rechunking after batch 108
# done with batch 108
# batch 109
# concatenating results of batch 109
# rechunking after batch 109
# done with batch 109
# batch 110
# concatenating results of batch 110
# rechunking after batch 110
# done with batch 110
# batch 111
# concatenating results of batch 111
# rechunking after batch 111
# done with batch 111
# batch 112
# concatenating results of batch 112
# rechunking after batch 112
# done with batch 112
# batch 113
# concatenating results of batch 113
# rechunking after batch 113
# done with batch 113
# batch 114
# concatenating results of batch 114
# rechunking after batch 114
# done with batch 114
# batch 115
# concatenating results of batch 115
# rechunking after batch 115
# done with batch 115
# batch 116
# concatenating results of batch 116
# rechunking after batch 116
# done with batch 116
# batch 117
# concatenating results of batch 117
# rechunking after batch 117
# done with batch 117
# batch 118
# concatenating results of batch 118
# rechunking after batch 118
# done with batch 118
# writing recent batches to file
# batch 119
# concatenating results of batch 119
# rechunking after batch 119
# done with batch 119
# batch 120
# concatenating results of batch 120
# rechunking after batch 120
# done with batch 120
# batch 121
# concatenating results of batch 121
# rechunking after batch 121
# done with batch 121
# batch 122
# concatenating results of batch 122
# rechunking after batch 122
# done with batch 122
# batch 123
# concatenating results of batch 123
# rechunking after batch 123
# done with batch 123
# batch 124
# concatenating results of batch 124
# rechunking after batch 124
# done with batch 124
# batch 125
# concatenating results of batch 125
# rechunking after batch 125
# done with batch 125
# batch 126
# concatenating results of batch 126
# rechunking after batch 126
# done with batch 126
# batch 127
# concatenating results of batch 127
# rechunking after batch 127
# done with batch 127
# batch 128
# concatenating results of batch 128
# rechunking after batch 128
# done with batch 128
# batch 129
# concatenating results of batch 129
# rechunking after batch 129
# done with batch 129
# batch 130
# concatenating results of batch 130
# rechunking after batch 130
# done with batch 130
# batch 131
# concatenating results of batch 131
# rechunking after batch 131
# done with batch 131
# batch 132
# concatenating results of batch 132
# rechunking after batch 132
# done with batch 132
# batch 133
# concatenating results of batch 133
# rechunking after batch 133
# done with batch 133
# batch 134
# concatenating results of batch 134
# rechunking after batch 134
# done with batch 134
# batch 135
# concatenating results of batch 135
# rechunking after batch 135
# done with batch 135
# batch 136
# concatenating results of batch 136
# rechunking after batch 136
# done with batch 136
# batch 137
# concatenating results of batch 137
# rechunking after batch 137
# done with batch 137
# batch 138
# concatenating results of batch 138
# rechunking after batch 138
# done with batch 138
# batch 139
# concatenating results of batch 139
# rechunking after batch 139
# done with batch 139
# batch 140
# concatenating results of batch 140
# rechunking after batch 140
# done with batch 140
# batch 141
# concatenating results of batch 141
# rechunking after batch 141
# done with batch 141
# batch 142
# concatenating results of batch 142
# rechunking after batch 142
# done with batch 142
# batch 143
# concatenating results of batch 143
# rechunking after batch 143
# done with batch 143
# writing recent batches to file
# batch 144
# concatenating results of batch 144
# rechunking after batch 144
# done with batch 144
# batch 145
# concatenating results of batch 145
# rechunking after batch 145
# done with batch 145
# batch 146
# concatenating results of batch 146
# rechunking after batch 146
# done with batch 146
# batch 147
# concatenating results of batch 147
# rechunking after batch 147
# done with batch 147
# batch 148
# concatenating results of batch 148
# rechunking after batch 148
# done with batch 148
# batch 149
# concatenating results of batch 149
# rechunking after batch 149
# done with batch 149
# batch 150
# concatenating results of batch 150
# rechunking after batch 150
# done with batch 150
# batch 151
# concatenating results of batch 151
# rechunking after batch 151
# done with batch 151
# batch 152
# concatenating results of batch 152
# rechunking after batch 152
# done with batch 152
# batch 153
# concatenating results of batch 153
# rechunking after batch 153
# done with batch 153
# batch 154
# concatenating results of batch 154
# rechunking after batch 154
# done with batch 154
# batch 155
# concatenating results of batch 155
# rechunking after batch 155
# done with batch 155
# batch 156
# concatenating results of batch 156
# rechunking after batch 156
# done with batch 156
# batch 157
# concatenating results of batch 157
# rechunking after batch 157
# done with batch 157
# batch 158
# concatenating results of batch 158
# rechunking after batch 158
# done with batch 158
# batch 159
# concatenating results of batch 159
# rechunking after batch 159
# done with batch 159
# batch 160
# concatenating results of batch 160
# rechunking after batch 160
# done with batch 160
# batch 161
# concatenating results of batch 161
# rechunking after batch 161
# done with batch 161
# batch 162
# concatenating results of batch 162
# rechunking after batch 162
# done with batch 162
# batch 163
# concatenating results of batch 163
# rechunking after batch 163
# done with batch 163
# batch 164
# concatenating results of batch 164
# rechunking after batch 164
# done with batch 164
# batch 165
# concatenating results of batch 165
# rechunking after batch 165
# done with batch 165
# batch 166
# concatenating results of batch 166
# rechunking after batch 166
# done with batch 166
# writing recent batches to file
# batch 167
# concatenating results of batch 167
# rechunking after batch 167
# done with batch 167
# batch 168
# concatenating results of batch 168
# rechunking after batch 168
# done with batch 168
# batch 169
# concatenating results of batch 169
# rechunking after batch 169
# done with batch 169
# batch 170
# concatenating results of batch 170
# rechunking after batch 170
# done with batch 170
# batch 171
# concatenating results of batch 171
# rechunking after batch 171
# done with batch 171
# batch 172
# concatenating results of batch 172
# rechunking after batch 172
# done with batch 172
# batch 173
# concatenating results of batch 173
# rechunking after batch 173
# done with batch 173
# batch 174
# concatenating results of batch 174
# rechunking after batch 174
# done with batch 174
# batch 175
# concatenating results of batch 175
# rechunking after batch 175
# done with batch 175
# batch 176
# concatenating results of batch 176
# rechunking after batch 176
# done with batch 176
# batch 177
# concatenating results of batch 177
# rechunking after batch 177
# done with batch 177
# batch 178
# concatenating results of batch 178
# rechunking after batch 178
# done with batch 178
# batch 179
# concatenating results of batch 179
# rechunking after batch 179
# done with batch 179
# batch 180
# concatenating results of batch 180
# rechunking after batch 180
# done with batch 180
# batch 181
# concatenating results of batch 181
# rechunking after batch 181
# done with batch 181
# batch 182
# concatenating results of batch 182
# rechunking after batch 182
# done with batch 182
# batch 183
# concatenating results of batch 183
# rechunking after batch 183
# done with batch 183
# batch 184
# concatenating results of batch 184
# rechunking after batch 184
# done with batch 184
# batch 185
# concatenating results of batch 185
# rechunking after batch 185
# done with batch 185
# batch 186
# concatenating results of batch 186
# rechunking after batch 186
# done with batch 186
# batch 187
# concatenating results of batch 187
# rechunking after batch 187
# done with batch 187
# batch 188
# concatenating results of batch 188
# rechunking after batch 188
# done with batch 188
# batch 189
# concatenating results of batch 189
# rechunking after batch 189
# done with batch 189
# batch 190
# concatenating results of batch 190
# rechunking after batch 190
# done with batch 190
# writing recent batches to file
# batch 191
# concatenating results of batch 191
# rechunking after batch 191
# done with batch 191
# batch 192
# concatenating results of batch 192
# rechunking after batch 192
# done with batch 192
# batch 193
# concatenating results of batch 193
# rechunking after batch 193
# done with batch 193
# batch 194
# concatenating results of batch 194
# rechunking after batch 194
# done with batch 194
# batch 195
# concatenating results of batch 195
# rechunking after batch 195
# done with batch 195
# batch 196
# concatenating results of batch 196
# rechunking after batch 196
# done with batch 196
# batch 197
# concatenating results of batch 197
# rechunking after batch 197
# done with batch 197
# batch 198
# concatenating results of batch 198
# rechunking after batch 198
# done with batch 198
# batch 199
# concatenating results of batch 199
# rechunking after batch 199
# done with batch 199
# batch 200
# concatenating results of batch 200
# rechunking after batch 200
# done with batch 200
# batch 201
# concatenating results of batch 201
# rechunking after batch 201
# done with batch 201
# batch 202
# concatenating results of batch 202
# rechunking after batch 202
# done with batch 202
# batch 203
# concatenating results of batch 203
# rechunking after batch 203
# done with batch 203
# batch 204
# concatenating results of batch 204
# rechunking after batch 204
# done with batch 204
# batch 205
# concatenating results of batch 205
# rechunking after batch 205
# done with batch 205
# batch 206
# concatenating results of batch 206
# rechunking after batch 206
# done with batch 206
# batch 207
# concatenating results of batch 207
# rechunking after batch 207
# done with batch 207
# batch 208
# concatenating results of batch 208
# rechunking after batch 208
# done with batch 208
# batch 209
# concatenating results of batch 209
# rechunking after batch 209
# done with batch 209
# batch 210
# concatenating results of batch 210
# rechunking after batch 210
# done with batch 210
# batch 211
# concatenating results of batch 211
# rechunking after batch 211
# done with batch 211
# batch 212
# concatenating results of batch 212
# rechunking after batch 212
# done with batch 212
# batch 213
# concatenating results of batch 213
# rechunking after batch 213
# done with batch 213
# writing recent batches to file
# batch 214
# concatenating results of batch 214
# rechunking after batch 214
# done with batch 214
# batch 215
# concatenating results of batch 215
# rechunking after batch 215
# done with batch 215
# batch 216
# concatenating results of batch 216
# rechunking after batch 216
# done with batch 216
# batch 217
# concatenating results of batch 217
# rechunking after batch 217
# done with batch 217
# batch 218
# concatenating results of batch 218
# rechunking after batch 218
# done with batch 218
# batch 219
# concatenating results of batch 219
# rechunking after batch 219
# done with batch 219
# batch 220
# concatenating results of batch 220
# rechunking after batch 220
# done with batch 220
# batch 221
# concatenating results of batch 221
# rechunking after batch 221
# done with batch 221
# batch 222
# concatenating results of batch 222
# rechunking after batch 222
# done with batch 222
# batch 223
# concatenating results of batch 223
# rechunking after batch 223
# done with batch 223
# batch 224
# concatenating results of batch 224
# rechunking after batch 224
# done with batch 224
# batch 225
# concatenating results of batch 225
# rechunking after batch 225
# done with batch 225
# batch 226
# concatenating results of batch 226
# rechunking after batch 226
# done with batch 226
# batch 227
# concatenating results of batch 227
# rechunking after batch 227
# done with batch 227
# batch 228
# concatenating results of batch 228
# rechunking after batch 228
# done with batch 228
# batch 229
# concatenating results of batch 229
# rechunking after batch 229
# done with batch 229
# batch 230
# concatenating results of batch 230
# rechunking after batch 230
# done with batch 230
# batch 231
# concatenating results of batch 231
# rechunking after batch 231
# done with batch 231
# batch 232
# concatenating results of batch 232
# rechunking after batch 232
# done with batch 232
# batch 233
# concatenating results of batch 233
# rechunking after batch 233
# done with batch 233
# batch 234
# concatenating results of batch 234
# rechunking after batch 234
# done with batch 234
# batch 235
# concatenating results of batch 235
# rechunking after batch 235
# done with batch 235
# batch 236
# concatenating results of batch 236
# rechunking after batch 236
# done with batch 236
# batch 237
# concatenating results of batch 237
# rechunking after batch 237
# done with batch 237
# writing recent batches to file
# batch 238
# concatenating results of batch 238
# rechunking after batch 238
# done with batch 238
# batch 239
# concatenating results of batch 239
# rechunking after batch 239
# done with batch 239
# batch 240
# concatenating results of batch 240
# rechunking after batch 240
# done with batch 240
# batch 241
# concatenating results of batch 241
# rechunking after batch 241
# done with batch 241
# batch 242
# concatenating results of batch 242
# rechunking after batch 242
# done with batch 242
# batch 243
# concatenating results of batch 243
# rechunking after batch 243
# done with batch 243
# batch 244
# concatenating results of batch 244
# rechunking after batch 244
# done with batch 244
# batch 245
# concatenating results of batch 245
# rechunking after batch 245
# done with batch 245
# batch 246
# concatenating results of batch 246
# rechunking after batch 246
# done with batch 246
# batch 247
# concatenating results of batch 247
# rechunking after batch 247
# done with batch 247
# batch 248
# concatenating results of batch 248
# rechunking after batch 248
# done with batch 248
# batch 249
# concatenating results of batch 249
# rechunking after batch 249
# done with batch 249
# batch 250
# concatenating results of batch 250
# rechunking after batch 250
# done with batch 250
# batch 251
# concatenating results of batch 251
# rechunking after batch 251
# done with batch 251
# batch 252
# concatenating results of batch 252
# rechunking after batch 252
# done with batch 252
# batch 253
# concatenating results of batch 253
# rechunking after batch 253
# done with batch 253
# batch 254
# concatenating results of batch 254
# rechunking after batch 254
# done with batch 254
# batch 255
# concatenating results of batch 255
# rechunking after batch 255
# done with batch 255
# batch 256
# concatenating results of batch 256
# rechunking after batch 256
# done with batch 256
# batch 257
# concatenating results of batch 257
# rechunking after batch 257
# done with batch 257
# batch 258
# concatenating results of batch 258
# rechunking after batch 258
# done with batch 258
# batch 259
# concatenating results of batch 259
# rechunking after batch 259
# done with batch 259
# batch 260
# concatenating results of batch 260
# rechunking after batch 260
# done with batch 260
# batch 261
# concatenating results of batch 261
# rechunking after batch 261
# done with batch 261
# writing recent batches to file
# batch 262
# concatenating results of batch 262
# rechunking after batch 262
# done with batch 262
# batch 263
# concatenating results of batch 263
# rechunking after batch 263
# done with batch 263
# batch 264
# concatenating results of batch 264
# rechunking after batch 264
# done with batch 264
# batch 265
# concatenating results of batch 265
# rechunking after batch 265
# done with batch 265
# batch 266
# concatenating results of batch 266
# rechunking after batch 266
# done with batch 266
# batch 267
# concatenating results of batch 267
# rechunking after batch 267
# done with batch 267
# batch 268
# concatenating results of batch 268
# rechunking after batch 268
# done with batch 268
# batch 269
# concatenating results of batch 269
# rechunking after batch 269
# done with batch 269
# batch 270
# concatenating results of batch 270
# rechunking after batch 270
# done with batch 270
# batch 271
# concatenating results of batch 271
# rechunking after batch 271
# done with batch 271
# batch 272
# concatenating results of batch 272
# rechunking after batch 272
# done with batch 272
# batch 273
# concatenating results of batch 273
# rechunking after batch 273
# done with batch 273
# batch 274
# concatenating results of batch 274
# rechunking after batch 274
# done with batch 274
# batch 275
# concatenating results of batch 275
# rechunking after batch 275
# done with batch 275
# batch 276
# concatenating results of batch 276
# rechunking after batch 276
# done with batch 276
# batch 277
# concatenating results of batch 277
# rechunking after batch 277
# done with batch 277
# batch 278
# concatenating results of batch 278
# rechunking after batch 278
# done with batch 278
# batch 279
# concatenating results of batch 279
# rechunking after batch 279
# done with batch 279
# batch 280
# concatenating results of batch 280
# rechunking after batch 280
# done with batch 280
# batch 281
# concatenating results of batch 281
# rechunking after batch 281
# done with batch 281
# batch 282
# concatenating results of batch 282
# rechunking after batch 282
# done with batch 282
# batch 283
# concatenating results of batch 283
# rechunking after batch 283
# done with batch 283
# batch 284
# concatenating results of batch 284
# rechunking after batch 284
# done with batch 284
# writing recent batches to file
# batch 285
# concatenating results of batch 285
# rechunking after batch 285
# done with batch 285
# batch 286
# concatenating results of batch 286
# rechunking after batch 286
# done with batch 286
# batch 287
# concatenating results of batch 287
# rechunking after batch 287
# done with batch 287
# batch 288
# concatenating results of batch 288
# rechunking after batch 288
# done with batch 288
# batch 289
# concatenating results of batch 289
# rechunking after batch 289
# done with batch 289
# batch 290
# concatenating results of batch 290
# rechunking after batch 290
# done with batch 290
# batch 291
# concatenating results of batch 291
# rechunking after batch 291
# done with batch 291
# batch 292
# concatenating results of batch 292
# rechunking after batch 292
# done with batch 292
# batch 293
# concatenating results of batch 293
# rechunking after batch 293
# done with batch 293
# batch 294
# concatenating results of batch 294
# rechunking after batch 294
# done with batch 294
# batch 295
# concatenating results of batch 295
# rechunking after batch 295
# done with batch 295
# batch 296
# concatenating results of batch 296
# rechunking after batch 296
# done with batch 296
# batch 297
# concatenating results of batch 297
# rechunking after batch 297
# done with batch 297
# batch 298
# concatenating results of batch 298
# rechunking after batch 298
# done with batch 298
# batch 299
# concatenating results of batch 299
# rechunking after batch 299
# done with batch 299
# batch 300
# concatenating results of batch 300
# rechunking after batch 300
# done with batch 300
# batch 301
# concatenating results of batch 301
# rechunking after batch 301
# done with batch 301
# batch 302
# concatenating results of batch 302
# rechunking after batch 302
# done with batch 302
# batch 303
# concatenating results of batch 303
# rechunking after batch 303
# done with batch 303
# batch 304
# concatenating results of batch 304
# rechunking after batch 304
# done with batch 304
# batch 305
# concatenating results of batch 305
# rechunking after batch 305
# done with batch 305
# batch 306
# concatenating results of batch 306
# rechunking after batch 306
# done with batch 306
# batch 307
# concatenating results of batch 307
# rechunking after batch 307
# done with batch 307
# batch 308
# concatenating results of batch 308
# rechunking after batch 308
# done with batch 308
# writing recent batches to file
# batch 309
# concatenating results of batch 309
# rechunking after batch 309
# done with batch 309
# batch 310
# concatenating results of batch 310
# rechunking after batch 310
# done with batch 310
# batch 311
# concatenating results of batch 311
# rechunking after batch 311
# done with batch 311
# batch 312
# concatenating results of batch 312
# rechunking after batch 312
# done with batch 312
# batch 313
# concatenating results of batch 313
# rechunking after batch 313
# done with batch 313
# batch 314
# concatenating results of batch 314
# rechunking after batch 314
# done with batch 314
# batch 315
# concatenating results of batch 315
# rechunking after batch 315
# done with batch 315
# batch 316
# concatenating results of batch 316
# rechunking after batch 316
# done with batch 316
# batch 317
# concatenating results of batch 317
# rechunking after batch 317
# done with batch 317
# batch 318
# concatenating results of batch 318
# rechunking after batch 318
# done with batch 318
# batch 319
# concatenating results of batch 319
# rechunking after batch 319
# done with batch 319
# batch 320
# concatenating results of batch 320
# rechunking after batch 320
# done with batch 320
# batch 321
# concatenating results of batch 321
# rechunking after batch 321
# done with batch 321
# batch 322
# concatenating results of batch 322
# rechunking after batch 322
# done with batch 322
# batch 323
# concatenating results of batch 323
# rechunking after batch 323
# done with batch 323
# batch 324
# concatenating results of batch 324
# rechunking after batch 324
# done with batch 324
# batch 325
# concatenating results of batch 325
# rechunking after batch 325
# done with batch 325
# batch 326
# concatenating results of batch 326
# rechunking after batch 326
# done with batch 326
# batch 327
# concatenating results of batch 327
# rechunking after batch 327
# done with batch 327
# batch 328
# concatenating results of batch 328
# rechunking after batch 328
# done with batch 328
# batch 329
# concatenating results of batch 329
# rechunking after batch 329
# done with batch 329
# batch 330
# concatenating results of batch 330
# rechunking after batch 330
# done with batch 330
# batch 331
# concatenating results of batch 331
# rechunking after batch 331
# done with batch 331
# writing recent batches to file
# batch 332
# concatenating results of batch 332
# rechunking after batch 332
# done with batch 332
# batch 333
# concatenating results of batch 333
# rechunking after batch 333
# done with batch 333
# batch 334
# concatenating results of batch 334
# rechunking after batch 334
# done with batch 334
# batch 335
# concatenating results of batch 335
# rechunking after batch 335
# done with batch 335
# batch 336
# concatenating results of batch 336
# rechunking after batch 336
# done with batch 336
# batch 337
# concatenating results of batch 337
# rechunking after batch 337
# done with batch 337
# batch 338
# concatenating results of batch 338
# rechunking after batch 338
# done with batch 338
# batch 339
# concatenating results of batch 339
# rechunking after batch 339
# done with batch 339
# batch 340
# concatenating results of batch 340
# rechunking after batch 340
# done with batch 340
# batch 341
# concatenating results of batch 341
# rechunking after batch 341
# done with batch 341
# batch 342
# concatenating results of batch 342
# rechunking after batch 342
# done with batch 342
# batch 343
# concatenating results of batch 343
# rechunking after batch 343
# done with batch 343
# batch 344
# concatenating results of batch 344
# rechunking after batch 344
# done with batch 344
# batch 345
# concatenating results of batch 345
# rechunking after batch 345
# done with batch 345
# batch 346
# concatenating results of batch 346
# rechunking after batch 346
# done with batch 346
# batch 347
# concatenating results of batch 347
# rechunking after batch 347
# done with batch 347
# batch 348
# concatenating results of batch 348
# rechunking after batch 348
# done with batch 348
# batch 349
# concatenating results of batch 349
# rechunking after batch 349
# done with batch 349
# batch 350
# concatenating results of batch 350
# rechunking after batch 350
# done with batch 350
# batch 351
# concatenating results of batch 351
# rechunking after batch 351
# done with batch 351
# batch 352
# concatenating results of batch 352
# rechunking after batch 352
# done with batch 352
# batch 353
# concatenating results of batch 353
# rechunking after batch 353
# done with batch 353
# batch 354
# concatenating results of batch 354
# rechunking after batch 354
# done with batch 354
# writing recent batches to file
# batch 355
# concatenating results of batch 355
# rechunking after batch 355
# done with batch 355
# batch 356
# concatenating results of batch 356
# rechunking after batch 356
# done with batch 356
# batch 357
# concatenating results of batch 357
# rechunking after batch 357
# done with batch 357
# batch 358
# concatenating results of batch 358
# rechunking after batch 358
# done with batch 358
# batch 359
# concatenating results of batch 359
# rechunking after batch 359
# done with batch 359
# batch 360
# concatenating results of batch 360
# rechunking after batch 360
# done with batch 360
# batch 361
# concatenating results of batch 361
# rechunking after batch 361
# done with batch 361
# batch 362
# concatenating results of batch 362
# rechunking after batch 362
# done with batch 362
# batch 363
# concatenating results of batch 363
# rechunking after batch 363
# done with batch 363
# batch 364
# concatenating results of batch 364
# rechunking after batch 364
# done with batch 364
# batch 365
# concatenating results of batch 365
# rechunking after batch 365
# done with batch 365
# batch 366
# concatenating results of batch 366
# rechunking after batch 366
# done with batch 366
# batch 367
# concatenating results of batch 367
# rechunking after batch 367
# done with batch 367
# batch 368
# concatenating results of batch 368
# rechunking after batch 368
# done with batch 368
# batch 369
# concatenating results of batch 369
# rechunking after batch 369
# done with batch 369
# batch 370
# concatenating results of batch 370
# rechunking after batch 370
# done with batch 370
# batch 371
# concatenating results of batch 371
# rechunking after batch 371
# done with batch 371
# batch 372
# concatenating results of batch 372
# rechunking after batch 372
# done with batch 372
# batch 373
# concatenating results of batch 373
# rechunking after batch 373
# done with batch 373
# batch 374
# concatenating results of batch 374
# rechunking after batch 374
# done with batch 374
# batch 375
# concatenating results of batch 375
# rechunking after batch 375
# done with batch 375
# batch 376
# concatenating results of batch 376
# rechunking after batch 376
# done with batch 376
# batch 377
# concatenating results of batch 377
# rechunking after batch 377
# done with batch 377
# batch 378
# concatenating results of batch 378
# rechunking after batch 378
# done with batch 378
# batch 379
# concatenating results of batch 379
# rechunking after batch 379
# done with batch 379
# writing recent batches to file
# batch 380
# concatenating results of batch 380
# rechunking after batch 380
# done with batch 380
# batch 381
# concatenating results of batch 381
# rechunking after batch 381
# done with batch 381
# batch 382
# concatenating results of batch 382
# rechunking after batch 382
# done with batch 382
# batch 383
# concatenating results of batch 383
# rechunking after batch 383
# done with batch 383
# batch 384
# concatenating results of batch 384
# rechunking after batch 384
# done with batch 384
# batch 385
# concatenating results of batch 385
# rechunking after batch 385
# done with batch 385
# batch 386
# concatenating results of batch 386
# rechunking after batch 386
# done with batch 386
# batch 387
# concatenating results of batch 387
# rechunking after batch 387
# done with batch 387
# batch 388
# concatenating results of batch 388
# rechunking after batch 388
# done with batch 388
# batch 389
# concatenating results of batch 389
# rechunking after batch 389
# done with batch 389
# batch 390
# concatenating results of batch 390
# rechunking after batch 390
# done with batch 390
# batch 391
# concatenating results of batch 391
# rechunking after batch 391
# done with batch 391
# batch 392
# concatenating results of batch 392
# rechunking after batch 392
# done with batch 392
# batch 393
# concatenating results of batch 393
# rechunking after batch 393
# done with batch 393
# batch 394
# concatenating results of batch 394
# rechunking after batch 394
# done with batch 394
# batch 395
# concatenating results of batch 395
# rechunking after batch 395
# done with batch 395
# batch 396
# concatenating results of batch 396
# rechunking after batch 396
# done with batch 396
# batch 397
# concatenating results of batch 397
# rechunking after batch 397
# done with batch 397
# batch 398
# concatenating results of batch 398
# rechunking after batch 398
# done with batch 398
# batch 399
# concatenating results of batch 399
# rechunking after batch 399
# done with batch 399
# batch 400
# concatenating results of batch 400
# rechunking after batch 400
# done with batch 400
# batch 401
# concatenating results of batch 401
# rechunking after batch 401
# done with batch 401
# batch 402
# concatenating results of batch 402
# rechunking after batch 402
# done with batch 402
# batch 403
# concatenating results of batch 403
# rechunking after batch 403
# done with batch 403
# writing recent batches to file
# batch 404
# concatenating results of batch 404
# rechunking after batch 404
# done with batch 404
# batch 405
# concatenating results of batch 405
# rechunking after batch 405
# done with batch 405
# batch 406
# concatenating results of batch 406
# rechunking after batch 406
# done with batch 406
# batch 407
# concatenating results of batch 407
# rechunking after batch 407
# done with batch 407
# batch 408
# concatenating results of batch 408
# rechunking after batch 408
# done with batch 408
# batch 409
# concatenating results of batch 409
# rechunking after batch 409
# done with batch 409
# batch 410
# concatenating results of batch 410
# rechunking after batch 410
# done with batch 410
# batch 411
# concatenating results of batch 411
# rechunking after batch 411
# done with batch 411
# batch 412
# concatenating results of batch 412
# rechunking after batch 412
# done with batch 412
# batch 413
# concatenating results of batch 413
# rechunking after batch 413
# done with batch 413
# batch 414
# concatenating results of batch 414
# rechunking after batch 414
# done with batch 414
# batch 415
# concatenating results of batch 415
# rechunking after batch 415
# done with batch 415
# batch 416
# concatenating results of batch 416
# rechunking after batch 416
# done with batch 416
# batch 417
# concatenating results of batch 417
# rechunking after batch 417
# done with batch 417
# batch 418
# concatenating results of batch 418
# rechunking after batch 418
# done with batch 418
# batch 419
# concatenating results of batch 419
# rechunking after batch 419
# done with batch 419
# batch 420
# concatenating results of batch 420
# rechunking after batch 420
# done with batch 420
# batch 421
# concatenating results of batch 421
# rechunking after batch 421
# done with batch 421
# batch 422
# concatenating results of batch 422
# rechunking after batch 422
# done with batch 422
# batch 423
# concatenating results of batch 423
# rechunking after batch 423
# done with batch 423
# batch 424
# concatenating results of batch 424
# rechunking after batch 424
# done with batch 424
# batch 425
# concatenating results of batch 425
# rechunking after batch 425
# done with batch 425
# batch 426
# concatenating results of batch 426
# rechunking after batch 426
# done with batch 426
# batch 427
# concatenating results of batch 427
# rechunking after batch 427
# done with batch 427
# writing recent batches to file
# batch 428
# concatenating results of batch 428
# rechunking after batch 428
# done with batch 428
# batch 429
# concatenating results of batch 429
# rechunking after batch 429
# done with batch 429
# batch 430
# concatenating results of batch 430
# rechunking after batch 430
# done with batch 430
# batch 431
# concatenating results of batch 431
# rechunking after batch 431
# done with batch 431
# batch 432
# concatenating results of batch 432
# rechunking after batch 432
# done with batch 432
# batch 433
# concatenating results of batch 433
# rechunking after batch 433
# done with batch 433
# batch 434
# concatenating results of batch 434
# rechunking after batch 434
# done with batch 434
# batch 435
# concatenating results of batch 435
# rechunking after batch 435
# done with batch 435
# batch 436
# concatenating results of batch 436
# rechunking after batch 436
# done with batch 436
# batch 437
# concatenating results of batch 437
# rechunking after batch 437
# done with batch 437
# batch 438
# concatenating results of batch 438
# rechunking after batch 438
# done with batch 438
# batch 439
# concatenating results of batch 439
# rechunking after batch 439
# done with batch 439
# batch 440
# concatenating results of batch 440
# rechunking after batch 440
# done with batch 440
# batch 441
# concatenating results of batch 441
# rechunking after batch 441
# done with batch 441
# batch 442
# concatenating results of batch 442
# rechunking after batch 442
# done with batch 442
# batch 443
# concatenating results of batch 443
# rechunking after batch 443
# done with batch 443
# batch 444
# concatenating results of batch 444
# rechunking after batch 444
# done with batch 444
# batch 445
# concatenating results of batch 445
# rechunking after batch 445
# done with batch 445
# batch 446
# concatenating results of batch 446
# rechunking after batch 446
# done with batch 446
# batch 447
# concatenating results of batch 447
# rechunking after batch 447
# done with batch 447
# batch 448
# concatenating results of batch 448
# rechunking after batch 448
# done with batch 448
# batch 449
# concatenating results of batch 449
# rechunking after batch 449
# done with batch 449

# %%
print("writing final batches to file")
df.write_parquet(datadir / "coords_parquet" / f"coords_{i}.parquet")
# Out:
# writing final batches to file

# %%
import io
uncompressed_pdb_size = 0
for path in batch:
    with gzip.open(path, 'rb') as file_obj:
        uncompressed_pdb_size += file_obj.seek(0, io.SEEK_END)
uncompressed_pdb_size
# Out:
# 419255352

# %%
df.estimated_size('b')
# Out:
# 211046689

# %%
sum(path.stat().st_size for path in batch)
# Out:
# 97648413

# %%
(datadir / "coords_parquet" / f"coords_{i}.parquet").stat().st_size
# Out:
# 56238480
